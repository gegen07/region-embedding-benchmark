# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/home/gegen07/dev/projects/region-embedding-benchmark/region-embedding/baselines/HGI/data/region_embedding.csv')
cta = pd.read_csv('../../data/cta_nyc.csv')

# %%
landuse = pd.read_csv('./data/nyc-landuse.csv')

# %%
landuse
# Out:
#       BoroCT2020         1         2         3         4         5         6  \
# 0        1000100  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1        1000201  0.000000  0.365854  0.024390  0.268293  0.000000  0.000000
# 2        1000202  0.037037  0.000000  0.203704  0.185185  0.055556  0.000000
# 3        1000500  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4        1000600  0.000000  0.151899  0.050633  0.594937  0.037975  0.006329
# ...          ...       ...       ...       ...       ...       ...       ...
# 2317     5030301  0.937330  0.029973  0.000000  0.001362  0.016349  0.000000
# 2318     5030302  0.940191  0.005582  0.000000  0.003987  0.015949  0.000000
# 2319     5031901  0.888268  0.016760  0.005587  0.016760  0.008380  0.000000
# 2320     5031902  0.864895  0.021041  0.001107  0.011074  0.004430  0.021041
# 2321     5032300  0.390769  0.018462  0.003077  0.018462  0.058462  0.080000
#
# ...

# %%
df = df.merge(cta, on='BoroCT2020')

# %%
df
# Out:
#              0         1         2         3         4         5         6  \
# 0    -0.113401  0.221726  0.248709  0.077020 -0.060134  0.055794  0.490052
# 1    -0.128716  0.236534  0.204198  0.117571 -0.054059  0.047339  0.504085
# 2    -0.149079  0.245855  0.209182  0.089902 -0.075227  0.027809  0.580560
# 3    -0.115189  0.132380  0.091106  0.042680 -0.062515 -0.005592  0.422359
# 4    -0.133988  0.098196  0.028089  0.045196 -0.071814 -0.006051  0.448095
# ...        ...       ...       ...       ...       ...       ...       ...
# 2305 -0.041940  0.096279  0.149854 -0.016725 -0.032059  0.207619  0.448415
# 2306 -0.069426  0.042580  0.071302 -0.003734 -0.047471  0.131354  0.406384
# 2307 -0.100517  0.063839  0.132358  0.001316 -0.094034  0.029290  0.428866
# 2308 -0.069168 -0.051618 -0.017376  0.239100 -0.093426  0.185633  0.305495
# 2309 -0.051057 -0.041412 -0.017474  0.194756 -0.066537  0.241834  0.342828
#
# ...

# %%
X = df.iloc[:, 0:64].values

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

for x in range(2, 20):
    kmeans = KMeans(n_clusters=x, random_state=0, n_init="auto")
    print(f"Silhueta k={x}, silhueta={silhouette_score(X, kmeans.fit_predict(X))}")
# Out:
# Silhueta k=2, silhueta=0.3378189232502672
# Silhueta k=3, silhueta=0.23348154529417461
# Silhueta k=4, silhueta=0.2600600985271986
# Silhueta k=5, silhueta=0.22869341960360526
# Silhueta k=6, silhueta=0.2068922793630046
# Silhueta k=7, silhueta=0.21255910262933303
# Silhueta k=8, silhueta=0.16859641544290033
# Silhueta k=9, silhueta=0.16261657211877242
# Silhueta k=10, silhueta=0.15460771390195507
# Silhueta k=11, silhueta=0.16343144735613574
# Silhueta k=12, silhueta=0.15037793470993865
# Silhueta k=13, silhueta=0.13475190716912275
# Silhueta k=14, silhueta=0.1347806543510293
# Silhueta k=15, silhueta=0.1354780455565061
# Silhueta k=16, silhueta=0.13819435180819306
# Silhueta k=17, silhueta=0.12902684552617072
# Silhueta k=18, silhueta=0.1313377786979673
# Silhueta k=19, silhueta=0.13033622401372186

# %%
kmeans = KMeans(n_clusters=11, random_state=0, n_init="auto")

# %%
df['labels'] = kmeans.fit_predict(X)

# %%
df.to_csv('HGI_clustered.csv', index=False)
